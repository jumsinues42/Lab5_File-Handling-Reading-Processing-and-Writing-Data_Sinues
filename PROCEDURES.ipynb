# %% [markdown]
# # 1. Writing to a File

# %%
# Step 1: Import Path from pathlib
from pathlib import Path
# Step 2: Define a custom folder in your Documents directory
output_dir = Path.home() / "Documents" / "PythonFiles"
output_dir.mkdir(exist_ok=True) # Creates folder if missing
# Step 3: Define the file path
file_path = output_dir / "Act5_example.txt"
# Step 4: Write text to the file
with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.")
# Step 5: Confirm that the file is saved
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\VICTUS\Documents\PythonFiles\Act5_example.txt

# %%
from pathlib import Path

# Step 2: Define your custom folder (Make sure this matches Procedure 2!)
output_dir = Path.home() / "Documents" / "Sinues_Activity_5"
output_dir.mkdir(exist_ok=True) 

# Step 3: Define the file path
file_path = output_dir / "Act5_example.txt"

# Step 4: Write text to the file - ADDED NEWLINES (\n)
with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.\n") # Added \n here
    file.write("Python makes file handling easy!\n") # Added \n here

# Step 5: Confirm
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\VICTUS\Documents\Sinues_Activity_5\Act5_example.txt

# %% [markdown]
# # 2. Reading from a File

# %%
# Step 1: Read the entire file content if it exists
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    print("File content:\n", content)

# Step 2: Read line-by-line
with open(file_path, "r", encoding="utf-8") as file:
    for line_number, line in enumerate(file, 1):
        print(f"Line {line_number}: {line.strip()}")
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.
# Python makes file handling easy!
#
# Line 1: Hello, Welcome to Python Programming!
# Line 2: File saved safely with pathlib.
# Line 3: Python makes file handling easy!

# %%
from pathlib import Path

# Step 1: Define path (Ensure it's the SAME folder as above)
output_dir = Path.home() / "Documents" / "Sinues_Activity_5"
file_path = output_dir / "Act5_example.txt"

# Step 2: Read and Filter
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        print("--- Filtered Content ---")
        for line_number, line in enumerate(file, 1):
            clean_line = line.strip()
            
            # This checks for "Python" regardless of case
            if "python" in clean_line.lower():
                word_count = len(clean_line.split())
                print(f"Line {line_number} ({word_count} words): {clean_line}")
else:
    print("Error: File not found. Please run the Write cell first!")
# Out:
# --- Filtered Content ---
# Line 1 (5 words): Hello, Welcome to Python Programming!
# Line 3 (5 words): Python makes file handling easy!

# %% [markdown]
# # 3. Appending Data

# %%
# Step 1: Open file in append mode
with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")

# Step 2: Confirm that data was added
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
# 1. Append multiple lines using a list and writelines()
more_lines = ["\nLine 4: This is from a list.\n", "Line 5: Another list line.\n"]
with open(file_path, "a", encoding="utf-8") as file:
    file.writelines(more_lines)

# 2. Append a line based on user input
user_note = input("Enter text to append: ")
with open(file_path, "a", encoding="utf-8") as file:
    file.write(user_note + "\n")

# %% [markdown]
# # 4. Safe File Operations with Backup

# %%
from pathlib import Path
from datetime import datetime
import shutil

# Step 2: Define working directory
backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True)

# Step 3: Define a function to write a file with backup
def write_with_backup(filename: str, content: str):
    file_path = backup_dir / filename
    # Create backup if file exists
    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_path = file_path.with_name(f"{file_path.stem}_backup_{timestamp}{file_path.suffix}")
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")
    
    # Write the new content
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)
        print(f"File saved: {file_path.name}")

# Step 4: Define a function to read the file content
def read_file(filename: str):
    file_path = backup_dir / filename
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    return content

# Step 5: Run demonstration
print("=== File Operations Demo ===")
print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

print("\n3. Reading file:")
print(read_file("demo.txt"))

print("\n4. Listing backups:")
for backup in backup_dir.glob("*backup*"):
    print("-", backup.name)
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# File saved: demo.txt
#
# 2. Updating file (with backup):
# Backup saved: demo_backup_20260406_132929.txt
# File saved: demo.txt
#
# 3. Reading file:
# Updated content
#
# 4. Listing backups:
# - demo_backup_20260406_132929.txt

# %%
# Step 1: Import additional libraries
from pathlib import Path
from datetime import datetime
import shutil

# Step 2: Define working directory
backup_dir = Path.home() / "Documents" / "Sinues_Activity_5"
backup_dir.mkdir(exist_ok=True)

# Step 3: Define a function to write a file with backup
def write_with_backup(filename: str, content: str):
    file_path = backup_dir / filename
    # Create backup if file exists
    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        # TRY IT: Added surname 'Sinues' to the backup format
        backup_name = f"Sinues_{file_path.stem}_backup_{timestamp}{file_path.suffix}"
        backup_path = file_path.with_name(backup_name)
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")
        
    # Write the new content
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)
        print(f"File saved: {file_path.name}")

# Step 4: Define a function to read the file content
def read_file(filename: str):
    file_path = backup_dir / filename
    if file_path.exists():
        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()
        return content
    return "File not found."

# TRY IT: Function to list backups for a specific filename
def list_backups_for(target_file: str):
    name_stem = Path(target_file).stem
    print(f"--- Backups for {target_file} ---")
    for backup in backup_dir.glob(f"*{name_stem}*backup*"):
        print("-", backup.name)

# Step 5: Run demonstration
print("=== File Operations Demo ===")

print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

print("\n3. Reading file:")
print(read_file("demo.txt"))

print("\n4. Listing backups:")
list_backups_for("demo.txt")
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# File saved: demo.txt
#
# 2. Updating file (with backup):
# Backup saved: Sinues_demo_backup_20260406_133023.txt
# File saved: demo.txt
#
# 3. Reading file:
# Updated content
#
# 4. Listing backups:
# --- Backups for demo.txt ---
# - Sinues_demo_backup_20260406_133023.txt

# %% [markdown]
# # 5. Menu-Driven File Manager

# %%
# Step 1: Import required modules
from pathlib import Path
from datetime import datetime
import shutil

# Step 2: Define your custom working directory in Documents
backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True) # Create folder if it doesn’t exist

# Step 3: Define the menu-driven file manager
def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = backup_dir / file_name
    
    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")
        
        choice = input("Choose an option (1-5): ")
        
        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")
            
        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")
            
        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")
                
        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")
                
        elif choice == "5":
            print("Exiting the file manager.")
            break
            
        else:
            print("Invalid choice. Please try again.")

# Step 4: Run the menu-driven tool
if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Content appended.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
#
# File Content:
#  Hello everybody
# What's up?
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Backup created: notes_backup_20260406_133540.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Exiting the file manager.

# %%
from pathlib import Path
from datetime import datetime
import shutil

def file_manager():
    # 1. Try It: Set working directory to Sinues_Activity_5
    working_dir = Path.home() / "Documents" / "Sinues_Activity_5"
    working_dir.mkdir(exist_ok=True)
    
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = working_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")
        print("6. List all backup files") # 3. Try It: Added 6th option
        
        choice = input("Choose an option (1-6): ")

        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
        elif choice == "3":
            if file_path.exists():
                print("\nFile Content:\n", file_path.read_text())
            else:
                print("File not found.")
        elif choice == "4":
            if file_path.exists():
                ts = datetime.now().strftime("%Y%m%d_%H%M%S")
                # 2. Try It: Surname included in the backup name
                bak_name = f"Sinues_{file_path.stem}_backup_{ts}{file_path.suffix}"
                bak_file = file_path.with_name(bak_name)
                shutil.copy2(file_path, bak_file)
                print(f"Backup saved as: {bak_file.name}")
        elif choice == "6": # Implementation of 6th option
            print("\nList of all Backups:")
            for b in working_dir.glob("*_backup_*"):
                print("-", b.name)
        elif choice == "5":
            print("Exiting.")
            break
        else:
            print("Invalid selection.")

if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
#
# File Content:
#  I love you
# I hate you
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
# Backup saved as: Sinues_Emotion_backup_20260406_134052.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
#
# List of all Backups:
# - Sinues_demo_backup_20260406_133023.txt
# - Sinues_Emotion_backup_20260406_134052.txt
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List all backup files
# Exiting.
